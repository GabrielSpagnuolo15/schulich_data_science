# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, precision_recall_curve
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv(r'C:\Users\gabri\Downloads\Train.csv')

# %%
df.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience
# 0  462809    Male           No   22        No     Healthcare              1.0  \
# 1  462643  Female          Yes   38       Yes       Engineer              NaN
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              NaN
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# 1        Average          3.0  Cat_4            A
# 2            Low          1.0  Cat_6            B
# 3           High          2.0  Cat_6            B
# 4           High          6.0  Cat_6            A

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               8068 non-null   int64
#  1   Gender           8068 non-null   object
#  2   Ever_Married     7928 non-null   object
#  3   Age              8068 non-null   int64
#  4   Graduated        7990 non-null   object
#  5   Profession       7944 non-null   object
#  6   Work_Experience  7239 non-null   float64
#  7   Spending_Score   8068 non-null   object
#  8   Family_Size      7733 non-null   float64
#  9   Var_1            7992 non-null   object
#  10  Segmentation     8068 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 693.5+ KB

# %%
#If less then 10 percent is missing, than remove
#Floats may be 1 or zero, don't assume because of nans
#For Var_1, may need to do research
#Might create a binary problem, might predict high spenders for example
df.describe(include='all')
# Out:
#                    ID Gender Ever_Married          Age Graduated Profession
# count     8068.000000   8068         7928  8068.000000      7990       7944  \
# unique            NaN      2            2          NaN         2          9
# top               NaN   Male          Yes          NaN       Yes     Artist
# freq              NaN   4417         4643          NaN      4968       2516
# mean    463479.214551    NaN          NaN    43.466906       NaN        NaN
# std       2595.381232    NaN          NaN    16.711696       NaN        NaN
# min     458982.000000    NaN          NaN    18.000000       NaN        NaN
# 25%     461240.750000    NaN          NaN    30.000000       NaN        NaN
# 50%     463472.500000    NaN          NaN    40.000000       NaN        NaN
# 75%     465744.250000    NaN          NaN    53.000000       NaN        NaN
# max     467974.000000    NaN          NaN    89.000000       NaN        NaN
#
#         Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# count       7239.000000           8068  7733.000000   7992         8068
# unique              NaN              3          NaN      7            4
# top                 NaN            Low          NaN  Cat_6            D
# freq                NaN           4878          NaN   5238         2268
# mean           2.641663            NaN     2.850123    NaN          NaN
# std            3.406763            NaN     1.531413    NaN          NaN
# min            0.000000            NaN     1.000000    NaN          NaN
# 25%            0.000000            NaN     2.000000    NaN          NaN
# 50%            1.000000            NaN     3.000000    NaN          NaN
# 75%            4.000000            NaN     4.000000    NaN          NaN
# max           14.000000            NaN     9.000000    NaN          NaN

# %%
# univariate analysis - first we check output variable and make sure it's balanced
df.groupby('Segmentation').count()
# Out:
#                 ID  Gender  Ever_Married   Age  Graduated  Profession
# Segmentation
# A             1972    1972          1938  1972       1948        1939  \
# B             1858    1858          1827  1858       1840        1836
# C             1970    1970          1947  1970       1955        1952
# D             2268    2268          2216  2268       2247        2217
#
#               Work_Experience  Spending_Score  Family_Size  Var_1
# Segmentation
# A                        1778            1972         1877   1953
# B                        1666            1858         1815   1845
# C                        1815            1970         1926   1949
# D                        1980            2268         2115   2245

# %%
# check continuous variables first > age, work experience, family size

import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,5))
sns.histplot(df['Age'], ax=ax1)
sns.histplot(df['Work_Experience'], ax=ax2)
sns.histplot(df['Family_Size'], ax=ax3)
# Out:
# <Axes: xlabel='Family_Size', ylabel='Count'>

# %%
# check continuous variables first > age, work experience, family size > compare them to output variable

import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,5))
sns.boxplot(x='Segmentation', y='Age', data=df, ax=ax1)
sns.boxplot(x='Segmentation', y='Work_Experience', data=df, ax=ax2)
sns.boxplot(x='Segmentation', y='Family_Size', data=df, ax=ax3)
# Out:
# <Axes: xlabel='Segmentation', ylabel='Family_Size'>

# %% [markdown]
# ## Initial Hypothesis
# Age and work experience seem to be strong predictors of the segment

# %%
df.columns
# Out:
# Index(['ID', 'Gender', 'Ever_Married', 'Age', 'Graduated', 'Profession',
#        'Work_Experience', 'Spending_Score', 'Family_Size', 'Var_1',
#        'Segmentation'],
#       dtype='object')

# %%
df.groupby(['Gender', 'Segmentation'])['ID'].count().unstack()
# Out:
# Segmentation     A    B     C     D
# Gender
# Female         909  861   922   959
# Male          1063  997  1048  1309

# %%
df.groupby(['Ever_Married', 'Segmentation'])['ID'].count().unstack()
# Out:
# Segmentation     A     B     C     D
# Ever_Married
# No             801   479   398  1607
# Yes           1137  1348  1549   609

# %%
df.groupby(['Ever_Married', 'Segmentation'])['ID'].count()
# Out:
# Ever_Married  Segmentation
# No            A                801
#               B                479
#               C                398
#               D               1607
# Yes           A               1137
#               B               1348
#               C               1549
#               D                609
# Name: ID, dtype: int64

# %%
df.groupby(['Graduated', 'Segmentation'])['ID'].count().unstack()
# Out:
# Segmentation     A     B     C     D
# Graduated
# No             729   508   348  1437
# Yes           1219  1332  1607   810

# %%
df.groupby(['Profession', 'Segmentation'])['ID'].count().unstack()
# Out:
# Segmentation     A    B     C    D
# Profession
# Artist         558  756  1065  137
# Doctor         199  143   140  206
# Engineer       259  189    75  176
# Entertainment  365  221   148  215
# Executive      125  183   175  116
# Healthcare     106  101   146  979
# Homemaker       73   55    28   90
# Lawyer         197  158   140  128
# Marketing       57   30    35  170

# %%
for i in ['Gender', 'Ever_Married','Graduated', 'Profession','Spending_Score']:
    print(df.groupby([i,'Segmentation'])['ID'].count().unstack())
# Out:
# Segmentation     A    B     C     D
# Gender
# Female         909  861   922   959
# Male          1063  997  1048  1309
# Segmentation     A     B     C     D
# Ever_Married
# No             801   479   398  1607
# Yes           1137  1348  1549   609
# Segmentation     A     B     C     D
# Graduated
# No             729   508   348  1437
# Yes           1219  1332  1607   810
# Segmentation     A    B     C    D
# Profession
# Artist         558  756  1065  137
# Doctor         199  143   140  206
# Engineer       259  189    75  176
# Entertainment  365  221   148  215
# Executive      125  183   175  116
# Healthcare     106  101   146  979
# Homemaker       73   55    28   90
# Lawyer         197  158   140  128
# Marketing       57   30    35  170
# Segmentation       A    B    C     D
# Spending_Score
# Average          343  590  903   138
# High             271  384  405   156
# Low             1358  884  662  1974

# %%
df[df['Segmentation']=='D'].describe(include='all')
#These are the low spenders
# Out:
#                    ID Gender Ever_Married          Age Graduated  Profession
# count     2268.000000   2268         2216  2268.000000      2247        2217  \
# unique            NaN      2            2          NaN         2           9
# top               NaN   Male           No          NaN        No  Healthcare
# freq              NaN   1309         1607          NaN      1437         979
# mean    463380.026896    NaN          NaN    33.390212       NaN         NaN
# std       2605.525629    NaN          NaN    15.680304       NaN         NaN
# min     458985.000000    NaN          NaN    18.000000       NaN         NaN
# 25%     461069.750000    NaN          NaN    22.000000       NaN         NaN
# 50%     463130.500000    NaN          NaN    29.000000       NaN         NaN
# 75%     465733.250000    NaN          NaN    38.000000       NaN         NaN
# max     467972.000000    NaN          NaN    89.000000       NaN         NaN
#
#         Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# count       1980.000000           2268  2115.000000   2245         2268
# unique              NaN              3          NaN      7            1
# top                 NaN            Low          NaN  Cat_6            D
# freq                NaN           1974          NaN   1297         2268
# mean           3.021717            NaN     3.232624    NaN          NaN
# std            3.622962            NaN     1.693600    NaN          NaN
# min            0.000000            NaN     1.000000    NaN          NaN
# 25%            0.000000            NaN     2.000000    NaN          NaN
# 50%            1.000000            NaN     3.000000    NaN          NaN
# 75%            6.000000            NaN     4.000000    NaN          NaN
# max           14.000000            NaN     9.000000    NaN          NaN

# %%
df[df['Segmentation']=='A'].describe(include='all')
# Out:
#                    ID Gender Ever_Married          Age Graduated Profession
# count     1972.000000   1972         1938  1972.000000      1948       1939  \
# unique            NaN      2            2          NaN         2          9
# top               NaN   Male          Yes          NaN       Yes     Artist
# freq              NaN   1063         1137          NaN      1219        558
# mean    463457.893002    NaN          NaN    44.924949       NaN        NaN
# std       2585.220444    NaN          NaN    16.406909       NaN        NaN
# min     458991.000000    NaN          NaN    18.000000       NaN        NaN
# 25%     461086.500000    NaN          NaN    33.000000       NaN        NaN
# 50%     463559.000000    NaN          NaN    41.000000       NaN        NaN
# 75%     465702.250000    NaN          NaN    52.000000       NaN        NaN
# max     467973.000000    NaN          NaN    89.000000       NaN        NaN
#
#         Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# count       1778.000000           1972  1877.000000   1953         1972
# unique              NaN              3          NaN      7            1
# top                 NaN            Low          NaN  Cat_6            A
# freq                NaN           1358          NaN   1213         1972
# mean           2.874578            NaN     2.439531    NaN          NaN
# std            3.603993            NaN     1.482015    NaN          NaN
# min            0.000000            NaN     1.000000    NaN          NaN
# 25%            0.000000            NaN     1.000000    NaN          NaN
# 50%            1.000000            NaN     2.000000    NaN          NaN
# 75%            5.000000            NaN     3.000000    NaN          NaN
# max           14.000000            NaN     9.000000    NaN          NaN

# %%
df[df['Segmentation']=='B'].describe(include='all')
# Out:
#                    ID Gender Ever_Married          Age Graduated Profession
# count     1858.000000   1858         1827  1858.000000      1840       1836  \
# unique            NaN      2            2          NaN         2          9
# top               NaN   Male          Yes          NaN       Yes     Artist
# freq              NaN    997         1348          NaN      1332        756
# mean    463520.253498    NaN          NaN    48.200215       NaN        NaN
# std       2550.208040    NaN          NaN    14.806443       NaN        NaN
# min     458989.000000    NaN          NaN    18.000000       NaN        NaN
# 25%     461454.250000    NaN          NaN    37.000000       NaN        NaN
# 50%     463479.500000    NaN          NaN    46.000000       NaN        NaN
# 75%     465737.500000    NaN          NaN    58.000000       NaN        NaN
# max     467974.000000    NaN          NaN    89.000000       NaN        NaN
#
#         Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# count       1666.000000           1858  1815.000000   1845         1858
# unique              NaN              3          NaN      7            1
# top                 NaN            Low          NaN  Cat_6            B
# freq                NaN            884          NaN   1232         1858
# mean           2.378151            NaN     2.696970    NaN          NaN
# std            3.225626            NaN     1.408615    NaN          NaN
# min            0.000000            NaN     1.000000    NaN          NaN
# 25%            0.000000            NaN     2.000000    NaN          NaN
# 50%            1.000000            NaN     2.000000    NaN          NaN
# 75%            3.750000            NaN     4.000000    NaN          NaN
# max           14.000000            NaN     9.000000    NaN          NaN

# %%
df[df['Segmentation']=='C'].describe(include='all')
#Generate dummy variables for categorical variables
# Out:
#                    ID Gender Ever_Married          Age Graduated Profession
# count     1970.000000   1970         1947  1970.000000      1955       1952  \
# unique            NaN      2            2          NaN         2          9
# top               NaN   Male          Yes          NaN       Yes     Artist
# freq              NaN   1048         1549          NaN      1607       1065
# mean    463576.043655    NaN          NaN    49.144162       NaN        NaN
# std       2633.377643    NaN          NaN    14.575090       NaN        NaN
# min     458982.000000    NaN          NaN    18.000000       NaN        NaN
# 25%     461485.250000    NaN          NaN    38.000000       NaN        NaN
# 50%     463739.000000    NaN          NaN    49.000000       NaN        NaN
# 75%     465791.750000    NaN          NaN    59.000000       NaN        NaN
# max     467969.000000    NaN          NaN    89.000000       NaN        NaN
#
#         Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# count       1815.000000           1970  1926.000000   1949         1970
# unique              NaN              3          NaN      7            1
# top                 NaN        Average          NaN  Cat_6            C
# freq                NaN            903          NaN   1496         1970
# mean           2.240771            NaN     2.974559    NaN          NaN
# std            3.046297            NaN     1.377322    NaN          NaN
# min            0.000000            NaN     1.000000    NaN          NaN
# 25%            0.000000            NaN     2.000000    NaN          NaN
# 50%            1.000000            NaN     3.000000    NaN          NaN
# 75%            3.000000            NaN     4.000000    NaN          NaN
# max           14.000000            NaN     9.000000    NaN          NaN

# %%
gender = pd.get_dummies(df['Gender'], dtype=int)

# %%
Ever_Married = pd.get_dummies(df['Ever_Married'], dtype=int)
Ever_Married.rename(columns={'Yes':"Married", 'No':"Not_Married"})
Graduated = pd.get_dummies(df['Graduated'], dtype=int)
Graduated.rename(columns={'Yes':"Graduated", 'No':"Not_Graduated"})
Profession = pd.get_dummies(df['Profession'], dtype=int)

# %%
Spending_score = pd.get_dummies(df['Spending_Score'], dtype=int)

# %%
gender
# Out:
#       Female  Male
# 0          0     1
# 1          1     0
# 2          1     0
# 3          0     1
# 4          1     0
# ...      ...   ...
# 8063       0     1
# 8064       0     1
# 8065       1     0
# 8066       1     0
# 8067       0     1
#
# [8068 rows x 2 columns]

# %%
new_df = pd.concat([df[['Age', 'Work_Experience', 'Family_Size']],gender,Ever_Married, Graduated, Profession, Spending_score, df['Segmentation']], axis=1)

# %%
new_df.dropna(inplace=True)

# %%
new_df.iloc[:,21]
# Out:
# 0       D
# 2       B
# 3       B
# 5       C
# 6       C
#        ..
# 8063    D
# 8064    D
# 8065    D
# 8066    B
# 8067    B
# Name: Segmentation, Length: 6969, dtype: object

# %%
knn = KNeighborsClassifier(n_neighbors=50)
knn.fit(new_df.iloc[:,:21], new_df.iloc[:,21])
# Out:
# KNeighborsClassifier(n_neighbors=50)

# %%
pred = knn.predict(new_df.iloc[:,:21])

# %%
print(accuracy_score(pred, new_df.iloc[:,21]))
# Out:
# 0.5058114507102884

# %%
df.groupby(['Spending_Score', 'Segmentation'])['ID'].count().unstack()
# Out:
# Segmentation       A    B    C     D
# Spending_Score
# Average          343  590  903   138
# High             271  384  405   156
# Low             1358  884  662  1974

# %%
# Combine low value users which are in A & D into one category, and high value B & C in another
def recategorization(x):
    if x == 'A':
        return 0
    elif x == 'D':
        return 0
    elif x == 'B':
        return 1
    elif x == 'C':
        return 1

# %%
new_df['Segmentation'] = new_df['Segmentation'].apply(recategorization)

# %%
knn = KNeighborsClassifier(n_neighbors=50)
knn.fit(new_df.iloc[:,:21], new_df.iloc[:,21])
pred = knn.predict(new_df.iloc[:,:21])
print(accuracy_score(pred, new_df.iloc[:,21]))
# Out:
# 0.7365475678002583

# %%
print(accuracy_score(pred, new_df.iloc[:,21]))
print(f1_score(pred, new_df.iloc[:,21]))
print(recall_score(pred, new_df.iloc[:,21]))
print(precision_score(pred, new_df.iloc[:,21]))
# Out:
# 0.7365475678002583
# 0.7398696514593369
# 0.7159309021113244
# 0.7654646731163881

# %%
log = LogisticRegression()
nb = GaussianNB()
knn = KNeighborsClassifier()
svc = SVC()

# %%
X_train, X_test, y_train, y_test = train_test_split(np.array(new_df.iloc[:,:21]), np.array(new_df.iloc[:,21]), test_size=0.2, random_state=42)

# %%
log.fit(X_train, y_train)
nb.fit(X_train, y_train)
knn.fit(X_train, y_train)
svc.fit(X_train, y_train)
# Out:
# c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# SVC()

# %%
pred_l = log.predict(X_test)
pred_nb = nb.predict(X_test)
pred_knn = knn.predict(X_test)
pred_svc = svc.predict(X_test)

# %%
print(f1_score(pred_l, y_test))
print(f1_score(pred_nb, y_test))
print(f1_score(pred_knn, y_test))
print(f1_score(pred_svc, y_test))
# Out:
# 0.7405797101449276
# 0.738690074274139
# 0.7281553398058253
# 0.71019809244314

# %%
pred_l_prob = log.predict_proba(X_test)

# %%
pred_l_prob
# Out:
# array([[0.41479935, 0.58520065],
#        [0.89121354, 0.10878646],
#        [0.5756704 , 0.4243296 ],
#        ...,
#        [0.89605025, 0.10394975],
#        [0.0960218 , 0.9039782 ],
#        [0.4212736 , 0.5787264 ]])

# %%
fpr, tpr, thresholds = roc_curve(y_test, pred_l_prob[:,1])

# %%
plt.plot(fpr,tpr)

# %%
gmeans = np.sqrt(tpr*(1-fpr))
gmeans
# Out:
# array([0.        , 0.03782347, 0.11347042, 0.12544627, 0.12535599,
#        0.13093006, 0.1308357 , 0.2068694 , 0.2136538 , 0.23282383,
#        0.6406257 , 0.641138  , 0.639125  , 0.63963528, 0.63558692,
#        0.63355303, 0.6315126 , 0.632016  , 0.63099249, 0.63149467,
#        0.62841169, 0.62891102, 0.61956252, 0.62054518, 0.61210199,
#        0.61258606, 0.61152162, 0.61200446, 0.60879743, 0.60927736,
#        0.60280698, 0.60328144, 0.60110745, 0.60157983, 0.59720465,
#        0.59767323, 0.59657355, 0.5970409 , 0.58927959, 0.58974051,
#        0.58412915, 0.58458532, 0.58232386, 0.58277792, 0.5724827 ,
#        0.57292838, 0.56828921, 0.56917233, 0.5680048 , 0.5656625 ,
#        0.56331046, 0.56418314, 0.5630016 , 0.5638711 , 0.56030602,
#        0.56073752, 0.55954319, 0.55997345, 0.55637229, 0.55765278,
#        0.55523345, 0.55280354, 0.55036289, 0.54791137, 0.54421339,
#        0.54628976, 0.54255227, 0.54296376, 0.53667196, 0.53707838,
#        0.52942366, 0.52982398, 0.51680421, 0.5171944 , 0.51797389,
#        0.5113244 , 0.51170871, 0.50360727, 0.50474024, 0.50063103,
#        0.49787271, 0.49861636, 0.49583853, 0.49657693, 0.4937793 ,
#        0.49237452, 0.49274019, 0.48991644, 0.49027974, 0.48886069,
#        0.48922268, 0.48637004, 0.48672965, 0.47660341, 0.47548997,
#        0.46360084, 0.46394261, 0.46092015, 0.46125943, 0.45668485,
#        0.45735595, 0.45117518, 0.44805282, 0.44490855, 0.4417419 ,
#        0.44206564, 0.42915582, 0.42946988, 0.42617887, 0.42286225,
#        0.41614973, 0.41675769, 0.4150601 , 0.41536251, 0.39260934,
#        0.38899074, 0.38349883, 0.38377784, 0.36872183, 0.36898969,
#        0.36512582, 0.36539069, 0.36148266, 0.35753191, 0.3577909 ,
#        0.34151907, 0.3417661 , 0.33967577, 0.33332613, 0.32902497,
#        0.32246567, 0.32071184, 0.31395926, 0.30937566, 0.28784769,
#        0.28284126, 0.26186012, 0.25634666, 0.25354497, 0.24820347,
#        0.24530041, 0.24547657, 0.21759172, 0.21089498, 0.20746557,
#        0.20043078, 0.18556284, 0.18569591, 0.10028725, 0.10035907,
#        0.        ])

# %%
thresholds[np.argmax(gmeans)]
# Out:
# 0.5309963132291506

# %%
knn_params = {'n_neighbors':range(3,300)}

rs_knn = RandomizedSearchCV(knn, knn_params, n_iter=10, cv=5, scoring='f1')
rs_knn.fit(X_train,y_train)
rs_knn.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=27)

# %%
svc_params = {'kernel': ['linear', 'poly','rbf']}

rs_svc = RandomizedSearchCV(svc, svc_params, n_iter=3, cv=5, scoring='f1')
rs_svc.fit(X_train,y_train)
rs_svc.best_estimator_
# Out:
# SVC(kernel='linear')

# %%
svc_best = SVC(kernel='linear')
knn_best = KNeighborsClassifier(n_neighbors=27)

svc_best.fit(X_train, y_train)
knn_best.fit(X_train, y_train)

pred_svc_best = svc_best.predict(X_test)
pred_knn_best = knn_best.predict(X_test)

print(f1_score(pred_svc_best, y_test))
print(f1_score(pred_knn_best, y_test))
# Out:
# 0.7420941672522839
# 0.7390396659707724

# %%
print(f1_score(pred_l, y_test))
# Out:
# 0.7405797101449276
