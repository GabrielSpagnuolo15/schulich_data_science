# %%
#Each break in code means a new box in the server
import pandas as pd
import sqlalchemy as sa
import requests

# %%
db_secret = {
    'drivername' : 'postgresql+psycopg2',
    'host'       : 'mmai5100postgres.canadacentral.cloudapp.azure.com',
    'port'       : '5432',
    'username'   : 'gabe15',
    'password'   : '2023!Schulich',
    'database'   : 'mban_db'
}

# %%
db_connection_url = sa.engine.URL.create(
    drivername = db_secret['drivername'],
    username   = db_secret['username'],
    password   = db_secret['password'],
    host       = db_secret['host'],
    port       = db_secret['port'],
    database   = db_secret['database']
)

# %%
db_connection_url
# Out:
# postgresql+psycopg2://gabe15:***@mmai5100postgres.canadacentral.cloudapp.azure.com:5432/mban_db

# %%
#Create an Engine
engine = sa.create_engine(db_connection_url)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 #Create an Engine
# ----> 2 engine = sa.create_engine(db_connection_url)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\create.py:601, in create_engine(url, **kwargs)
#     599         if k in kwargs:
# ...

# %%
with engine.connect() as connection:
    data = pd.read_sql(sql='SELECT * FROM dimensions.date_dimension;', con=connection)
# Out:
#      _id          report_date  previous_day_total_doses_administered
# 940  941  2023-07-30T00:00:00                                    623  \
# 941  942  2023-07-31T00:00:00                                    226
# 942  943  2023-08-01T00:00:00                                   1085
# 943  944  2023-08-02T00:00:00                                   1395
# 944  945  2023-08-03T00:00:00                                   1016
#
#      previous_day_at_least_one  previous_day_fully_vaccinated
# 940                         29                             19  \
# 941                          6                              4
# 942                         48                             31
# 943                         72                             54
# 944                         61                             37
#
#     previous_day_3doses  total_doses_administered
# 940                  27                  38844184  \
# 941                  15                  38844410
# ...

# %%
data = pd.read_sql(sql='SELECT * FROM dimensions.date_dimension;', con=engine)
data

# %%
db_secret = {
    'drivername' : 'postgresql+psycopg2',
    'host'       : 'mmai5100postgres.canadacentral.cloudapp.azure.com',
    'port'       : '5432',
    'username'   : 'gabe15',
    'password'   : '2023!Schulich',
    'database'   : 'gabe15_db'
}
# Out:
#      new_doses  new_doses_unvaccinated  new_doses_one_vaccine
# 0          0.0                     0.0                    0.0  \
# 1       4615.0                    64.0                    2.0
# 2       5396.0                     7.0                    3.0
# 3       5995.0                     3.0                   -1.0
# 4       9687.0                    27.0                   20.0
# ..         ...                     ...                    ...
# 940      623.0                   596.0                   17.0
# 941      226.0                   220.0                    4.0
# 942     1085.0                  1042.0                   26.0
# 943     1395.0                  1323.0                   54.0
# 944     1016.0                   955.0                   37.0
#
#      new_doses_two_vaccines  new_doses_three_vaccines
# 0                       0.0                       0.0
# 1                    4547.0                       2.0
# 2                    5383.0                       3.0
# ...

# %%
db_connection_url = sa.engine.URL.create(
    drivername = db_secret['drivername'],
    username   = db_secret['username'],
    password   = db_secret['password'],
    host       = db_secret['host'],
    port       = db_secret['port'],
    database   = db_secret['database']
)

# %%
print(db_connection_url)

# %%
covid_19_vaccines['total_doses_administered'] = covid_19_vaccines['total_doses_administered'].map({'None': 0})
covid_19_vaccines['total_individuals_at_least_one'] = covid_19_vaccines['total_individuals_at_least_one'].map({'None': 0})
covid_19_vaccines['total_individuals_partially_vaccinated'] = covid_19_vaccines['total_individuals_partially_vaccinated'].map({'None': 0})
covid_19_vaccines['total_individuals_fully_vaccinated'] = covid_19_vaccines['total_individuals_fully_vaccinated'].map({'None': 0})
covid_19_vaccines['total_individuals_3doses'] = covid_19_vaccines['total_individuals_3doses'].map({'None': 0})
