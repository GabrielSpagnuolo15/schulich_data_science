# %%
import pandas as pd
import sqlalchemy as sa
import requests

# %%
resource_id = '71802bd8-1574-4ee9-911a-62a00160fa19'
limit = 1500
offset = 0

# %%
api_url = 'https://data.ontario.ca/api/3/action/datastore_search?resource_id={}&limit={}&offset={}'.format(resource_id, limit, offset)
print(api_url)
# Out:
# https://data.ontario.ca/api/3/action/datastore_search?resource_id=71802bd8-1574-4ee9-911a-62a00160fa19&limit=1500&offset=0

# %%
api_response = requests.get(api_url)
api_response
# Out:
# <Response [200]>

# %%
data = api_response.json()
data
# Out:
# {'help': 'https://data.ontario.ca/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'limit': 1500,
#   'offset': 0,
#   'records_format': 'objects',
#   'resource_id': '71802bd8-1574-4ee9-911a-62a00160fa19',
#   'total_estimation_threshold': None,
#   'records': [{'_id': 1,
#     'Program': 'Youth Science and Technology Outreach Program',
#     'ProjectNumber': 'YO05-01-004',
#     'ProjectTitle': 'Partnership Project Accessiblity Initiative',
#     'ProjectDescription': "In conjunction with postsecondary institutions across Canada, the Let's Talk Science Partnership Program provides postsecondary science students, largely graduate students, with meaningful volunteer opportunities to interact with youth in their communities.",
#     'AreaPrimary': 10,
#     'AreaSecondary': 10,
#     'DisciplinePrimary': 99998,
#     'DisciplineSecondary': 99998,
#     'Round': 1,
#     'ApprovalDate': '2005-07-05T00:00:00',
# ...

# %%
data['result']['records']
# Out:
# [{'_id': 1,
#   'Program': 'Youth Science and Technology Outreach Program',
#   'ProjectNumber': 'YO05-01-004',
#   'ProjectTitle': 'Partnership Project Accessiblity Initiative',
#   'ProjectDescription': "In conjunction with postsecondary institutions across Canada, the Let's Talk Science Partnership Program provides postsecondary science students, largely graduate students, with meaningful volunteer opportunities to interact with youth in their communities.",
#   'AreaPrimary': 10,
#   'AreaSecondary': 10,
#   'DisciplinePrimary': 99998,
#   'DisciplineSecondary': 99998,
#   'Round': 1,
#   'ApprovalDate': '2005-07-05T00:00:00',
#   'LeadResearchInstitution': "Let's Talk Science",
#   'City': 'London',
#   'OntarioCommitment': '$150,000',
#   'TotalProjectCosts': '$629,000',
#   'Keyword': None,
#   'Expenditure_Type': 'Operating',
#   'Salutation': 'N/A',
#   'First_Name': 'N/A',
#   'Middle_Name': None,
#   'Last_Name': 'N/A',
#   'OIA_Area': 'Not Applicable'},
#  {'_id': 2,
# ...

# %%
COVID19_Vaccine_data = pd.DataFrame(data['result']['records'])
COVID19_Vaccine_data
# Out:
#     _id                                        Program ProjectNumber
# 0     1  Youth Science and Technology Outreach Program   YO05-01-004  \
# 1     2  Youth Science and Technology Outreach Program   YO06-03-035
# 2     3  Youth Science and Technology Outreach Program   YO05-02-031
# 3     4  Youth Science and Technology Outreach Program   YO05-02-029
# 4     5  Youth Science and Technology Outreach Program   YO05-02-028
# 5     6  Youth Science and Technology Outreach Program   YO05-02-027
# 6     7  Youth Science and Technology Outreach Program   YO06-03-034
# 7     8  Youth Science and Technology Outreach Program   YO05-02-033
# 8     9  Youth Science and Technology Outreach Program   YO06-03-053
# 9    10  Youth Science and Technology Outreach Program   YO06-03-042
# 10   11  Youth Science and Technology Outreach Program   YO06-03-049
# 11   12  Youth Science and Technology Outreach Program   YO06-03-048
# 12   13  Youth Science and Technology Outreach Program   YO05-02-025
# ...

# %%
null_counts = COVID19_Vaccine_data.isnull().sum()
print(null_counts)
# Out:
# _id                         0
# Program                     0
# ProjectNumber               0
# ProjectTitle                0
# ProjectDescription          0
# AreaPrimary                 0
# AreaSecondary               0
# DisciplinePrimary           0
# DisciplineSecondary         0
# Round                       0
# ApprovalDate                0
# LeadResearchInstitution     0
# City                        0
# OntarioCommitment           0
# TotalProjectCosts           0
# Keyword                    32
# Expenditure_Type            0
# Salutation                  0
# First_Name                  0
# Middle_Name                42
# Last_Name                   0
# OIA_Area                    0
# dtype: int64

# %%
relevant_columns = ['First_Name', 'Middle_Name', 'Last_Name', ]
clean_total_pay = salary_data[relevant_columns]
clean_total_pay
