# %%
import requests as r
import pandas as pd

# %%
basic_gdelt_url = "https://api.gdeltproject.org/api/v2/doc/doc"

# %%
params = {
    'query': 'Islamic State',
    'mode': 'artlist',
    'format': 'json',
}

# %%
response = r.get(basic_gdelt_url, params=params)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()

# %%
data
# Out:
# {'articles': [{'url': 'https://www.alwatanvoice.com/arabic/news/2023/09/25/1536280.html',
#    'url_mobile': '',
#    'title': 'فلسطين تشارك في المؤتمر الثاني عشر لوزراء الثقافة في العالم الإسلامي',
#    'seendate': '20230925T140000Z',
#    'socialimage': 'https://images.alwatanvoice.com/news/large/70ca94c7-a611-4d2e-8f68-6e2e7d06962e.jpg',
#    'domain': 'alwatanvoice.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Israel'},
#   {'url': 'https://www.in.gr/2023/09/24/world/syllipseis-sto-iran-eksoudeterothikan-30-vomves-xeiropedes-se-28-atoma-gia-diasyndeseis-islamiko-kratos/',
#    'url_mobile': 'https://www.in.gr/2023/09/24/world/syllipseis-sto-iran-eksoudeterothikan-30-vomves-xeiropedes-se-28-atoma-gia-diasyndeseis-islamiko-kratos/amp/',
#    'title': 'Συλλήψεις στο Ιράν : Εξουδετερώθηκαν 30 βόμβες , χειροπέδες σε 28 άτομα για διασυνδέσεις με το Ισλαμικό Κράτος',
#    'seendate': '20230924T154500Z',
# ...
